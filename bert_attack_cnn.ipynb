# %%
# %%time

from bert_attack import *

min_length = 30
max_length = 300
number_examples = 100

models = ['cnn']
datasets = ['hard']

main(models, datasets, min_length, max_length, number_examples)
# Out:
# @@@ BEGINNING ATTACK: [ MODEL: `CNN` | DATASET: `HARD` ] @@@
#
#    ## Sampling Examples from `HARD` Dataset:
#       # Total Number of Qualified Examples: 44,804
#       # Total Number of Randomly Selected Examples: 100
#
#    ## Running BERT Synonym-level Attack on `CNN` Model:
#         # Original Example: “عماني”. . اجراءات تسجيل الحجز تتاخر جدا
#           > Predication Label: Poor
#           > Predication Score: 0.2887592613697052
#             * Targeted Word: تسجيل
#             * Synonym Word: فك
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “عماني”. . اجراءات فك الحجز تتاخر جدا
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.28718170523643494
#
#         # Original Example: “الامان والراحة ...”. التعامل من قبل الرسبشن جيد وخاصة الاخ اكرم وهو اسم على مسمى .. لا شي .
#           > Predication Label: Fair
#           > Predication Score: 0.27501651644706726
#             * Targeted Word: اسم
#             * Synonym Word: اسما
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الامان والراحة ...”. التعامل من قبل الرسبشن جيد وخاصة الاخ اكرم وهو اسما على مسمى .. لا شي .
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2746441066265106
#
#         # Original Example: ضعيف. . يمنع استقبال الزور مع اني حاجز شقه بغرفتين وانا بمفردي
#           > Predication Label: Poor
#           > Predication Score: 0.2967999577522278
#             * Targeted Word: اني
#             * Synonym Word: انه
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ضعيف. . يمنع استقبال الزور مع انه حاجز شقه بغرفتين وانا بمفردي
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2895600199699402
#
#         # Original Example: “رخيص سعره مقارنة بمستواه”. انصح فيه جدا ممتاز كل شي فيه.
#           > Predication Label: Poor
#           > Predication Score: 0.27180373668670654
#             * Targeted Word: جدا
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “رخيص سعره مقارنة بمستواه”. انصح فيه . ممتاز كل شي فيه.
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2678331732749939
#
#         # Original Example: ضعيف. الموقع فقط. الغرف سيئة ووصخة وروائح كريهه والسرير غير مريح ومزعج
#           > Predication Label: Poor
#           > Predication Score: 0.2784454822540283
#             * Targeted Word: سيئة
#             * Synonym Word: مو
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ضعيف. الموقع فقط. الغرف مو ووصخة وروائح كريهه والسرير غير مريح ومزعج
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2912735044956207
#
#         # Original Example: استثنائي. ممتميز بالجودة مع حسن التعامل رائع جدا.
#           > Predication Label: Excellent
#           > Predication Score: 0.32246270775794983
#             * Targeted Word: رائع
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. ممتميز بالجودة مع حسن التعامل . جدا.
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2599659860134125
#
#         # Original Example: “روعة جداً”. المطعم  الموقع القريب للحرم. موقف السيارة سعره غالي
#           > Predication Label: Fair
#           > Predication Score: 0.2993226647377014
#             * Targeted Word: المطعم
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “روعة جداً”. . الموقع القريب للحرم. موقف السيارة سعره غالي
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.28515908122062683
#
#         # Original Example: “الملبغ خساره ف الفندق”. . تعامل الموظفين جدن سيئ
#           > Predication Label: Poor
#           > Predication Score: 0.28870636224746704
#             * Targeted Word: الموظفين
#             * Synonym Word: الفندق
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الملبغ خساره ف الفندق”. . تعامل الفندق جدن سيئ
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2773456871509552
#
#         # Original Example: ضعيف. . الرسبشن كان صغير واللفيت لازم اقعد ١٠ دقايق عشان اطلع لغرفتي
#           > Predication Label: Fair
#           > Predication Score: 0.2831672132015228
#             * Targeted Word: صغير
#             * Synonym Word: ممتاز
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ضعيف. . الرسبشن كان ممتاز واللفيت لازم اقعد ١٠ دقايق عشان اطلع لغرفتي
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2774805426597595
#
#         # Original Example: “اسوأ منتجع”. لاشي سوا البحر. الاستقبال سئ ومدير التسويق أخلاقه سيئه جدا ويتصرف بعنجهيه وتعالى ولا أعلم سبب تواجده بالاستقبال
#           > Predication Label: Poor
#           > Predication Score: 0.30144283175468445
#             * Targeted Word: جدا
#             * Synonym Word: للغاية
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “اسوأ منتجع”. لاشي سوا البحر. الاستقبال سئ ومدير التسويق أخلاقه سيئه للغاية ويتصرف بعنجهيه وتعالى ولا أعلم سبب تواجده بالاستقبال
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2952723503112793
#
#         # Original Example: “الفندق عنوان للغبن”. . الفندق لايستحق نصف المبلغ الذي دفعته فيه نتيجة سوء الخدمة وانعدام النظافة وتهالك الاثاث
#           > Predication Label: Fair
#           > Predication Score: 0.29493218660354614
#             * Targeted Word: الاثاث
#             * Synonym Word: …
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الفندق عنوان للغبن”. . الفندق لايستحق نصف المبلغ الذي دفعته فيه نتيجة سوء الخدمة وانعدام النظافة وتهالك …
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2927093207836151
#
#         # Original Example: “للآسترخاء عنوان”. الراحه والموقع والهدوء. السعر للاجنحه
#           > Predication Label: Good
#           > Predication Score: 0.2722102403640747
#             * Targeted Word: والموقع
#             * Synonym Word: النفسية
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “للآسترخاء عنوان”. الراحه النفسية والهدوء. السعر للاجنحه
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.26411089301109314
#
#         # Original Example: “شكرا”. تصميم الغرفة. تستطيع سماع اصوات الغرفة التي بجانبك
#           > Predication Label: Fair
#           > Predication Score: 0.2832287549972534
#             * Targeted Word: اصوات
#             * Synonym Word: أصوات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “شكرا”. تصميم الغرفة. تستطيع سماع أصوات الغرفة التي بجانبك
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2908908426761627
#
#         # Original Example: جيد. البلكونه. لايتم مراعاة ظروف النزيل من حيث التأخير في check out كذلك موظغي الاستقبال لم يعجبوني
#           > Predication Label: Poor
#           > Predication Score: 0.29159799218177795
#             * Targeted Word: موظغي
#             * Synonym Word: طاقم
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. البلكونه. لايتم مراعاة ظروف النزيل من حيث التأخير في check out كذلك طاقم الاستقبال لم يعجبوني
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.30226820707321167
#
#         # Original Example: رائع. الراحةالهدوء. الاسعار المبالغ فيها
#           > Predication Label: Fair
#           > Predication Score: 0.28017571568489075
#             * Targeted Word: المبالغ
#             * Synonym Word: مبالغا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: رائع. الراحةالهدوء. الاسعار مبالغا فيها
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.273275762796402
#
#         # Original Example: “موقع قريب وطاقم متعاون”. كل شيء جيد الموقع والفندق بشكل عامطاقم متعاون قمت بالدخول مبكرا دون دفع رسوم. لم يكن هناك ارسال للجوال في الغرفة اغلب الوقت وبالتالي لا انترنت
#           > Predication Label: Fair
#           > Predication Score: 0.27607208490371704
#             * Targeted Word: قريب
#             * Synonym Word: رائع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “موقع رائع وطاقم متعاون”. كل شيء جيد الموقع والفندق بشكل عامطاقم متعاون قمت بالدخول مبكرا دون دفع رسوم. لم يكن هناك ارسال للجوال في الغرفة اغلب الوقت وبالتالي لا انترنت
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.28650963306427
#
#         # Original Example: استثنائي. كان موظفي الاستقبال راقيين في التعامل.
#           > Predication Label: Poor
#           > Predication Score: 0.2978825867176056
#             * Targeted Word: موظفي
#             * Synonym Word: موظفو
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. كان موظفو الاستقبال راقيين في التعامل.
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.3120822608470917
#
#         # Original Example: “يستحق التجربة مرة اخرى”. كل شي من الطاقم الى الترتيب والنظافة. لاشي
#           > Predication Label: Fair
#           > Predication Score: 0.2761845588684082
#             * Targeted Word: الطاقم
#             * Synonym Word: المياه
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “يستحق التجربة مرة اخرى”. كل شي من المياه الى الترتيب والنظافة. لاشي
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2954584062099457
#
#         # Original Example: “الفندق ممتاز”. نظافة الفندقخدمة الغرفالافطار المجاني بنظام البوفيه المفتوحالواي فاي سريعركن السيارات المجانيرحابه صدر المستقبلين. لا شيئ الفندق جميل من كل النواحي واوصي به للسكن الممتع والجميل
#           > Predication Label: Fair
#           > Predication Score: 0.27953603863716125
#             * Targeted Word: للسكن
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الفندق ممتاز”. نظافة الفندقخدمة الغرفالافطار المجاني بنظام البوفيه المفتوحالواي فاي سريعركن السيارات المجانيرحابه صدر المستقبلين. لا شيئ الفندق جميل من كل النواحي واوصي به . الممتع والجميل
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2794901132583618
#
#         # Original Example: “ممتاز”. الفندق بشكل عام ممتاز وهو دايم المفضل عندي للحجز. مخده السرير كان فيها اثار بقع
#           > Predication Label: Fair
#           > Predication Score: 0.25359809398651123
#             * Targeted Word: السرير
#             * Synonym Word: النوم
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ممتاز”. الفندق بشكل عام ممتاز وهو دايم المفضل عندي للحجز. مخده النوم كان فيها اثار بقع
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2547830045223236
#
#         # Original Example: رائع. . عدم الالتزام بوقت بركة السباحة
#           > Predication Label: Fair
#           > Predication Score: 0.28788232803344727
#             * Targeted Word: عدم
#             * Synonym Word: في
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: رائع. . في الالتزام بوقت بركة السباحة
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.27991700172424316
#
#         # Original Example: “للضرورة يمكن يكون سكن للعائلة”. الإفطار. الموقع
#           > Predication Label: Poor
#           > Predication Score: 0.2876746654510498
#             * Targeted Word: سكن
#             * Synonym Word: مناسبة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “للضرورة يمكن يكون مناسبة للعائلة”. الإفطار. الموقع
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.27411991357803345
#
#         # Original Example: “ممتاز”. النظافة استجمام واحيانا  هدوء. غالباً مافي هدوء
#           > Predication Label: Poor
#           > Predication Score: 0.2670907974243164
#             * Targeted Word: استجمام
#             * Synonym Word: ممتازة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ممتاز”. النظافة ممتازة واحيانا هدوء. غالباً مافي هدوء
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.26343682408332825
#
#         # Original Example: “رائع”. استقبال  رائع. عدم حجز رقم الغرفة المطلوبة
#           > Predication Label: Fair
#           > Predication Score: 0.2866683006286621
#             * Targeted Word: رقم
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “رائع”. استقبال رائع. عدم حجز . الغرفة المطلوبة
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.284618616104126
#
#         # Original Example: “زيارة مسجد الرسول صلى الله عليه وسلم”. كل شي بأستثناء البوفية مافيه تنوع كثير وماهو قد الفندق. لاشي
#           > Predication Label: Poor
#           > Predication Score: 0.26616954803466797
#             * Targeted Word: الله
#             * Synonym Word: لله
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “زيارة مسجد الرسول صلى لله عليه وسلم”. كل شي بأستثناء البوفية مافيه تنوع كثير وماهو قد الفندق. لاشي
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2675198018550873
#
#         # Original Example: “للأسف إستقبال سئ الحجز من إسبوع ومع ذلك لما وصلنا انتظرنا ساعتين حتی ندخل”. المكان بعيد عن الصخب. الفندق كله وأسعاره
#           > Predication Label: Fair
#           > Predication Score: 0.28775855898857117
#             * Targeted Word: سئ
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “للأسف إستقبال . الحجز من إسبوع ومع ذلك لما وصلنا انتظرنا ساعتين حتی ندخل”. المكان بعيد عن الصخب. الفندق كله وأسعاره
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.27796033024787903
#
#         # Original Example: “جيد”. الموقع ممتاز الافطار متنوع ولذيذرحابة وحسن معاملة الموظفين. توجد رائحه كريه في ممرات الدور الذي سكنا به الانترت ليس بالمجان يجب دفع رسوم
#           > Predication Label: Excellent
#           > Predication Score: 0.2777837812900543
#             * Targeted Word: ممتاز
#             * Synonym Word: جيد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيد”. الموقع جيد الافطار متنوع ولذيذرحابة وحسن معاملة الموظفين. توجد رائحه كريه في ممرات الدور الذي سكنا به الانترت ليس بالمجان يجب دفع رسوم
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2963285446166992
#
#         # Original Example: “جيد جداً”. كل شي. رائحة الغرفه من التدخين
#           > Predication Label: Poor
#           > Predication Score: 0.28903433680534363
#             * Targeted Word: رائحة
#             * Synonym Word: خلو
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيد جداً”. كل شي. خلو الغرفه من التدخين
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.28255799412727356
#
#         # Original Example: “الطائف”. الموقع. دورات المياه والاثاث
#           > Predication Label: Fair
#           > Predication Score: 0.2830713093280792
#             * Targeted Word: والاثاث
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الطائف”. الموقع. دورات المياه .
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2758116126060486
#
#         # Original Example: استثنائي. جميل ونظيف وطاقم متعاون وسعر مقبول جدا.
#           > Predication Label: Fair
#           > Predication Score: 0.2712227702140808
#             * Targeted Word: جميل
#             * Synonym Word: رائع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. رائع ونظيف وطاقم متعاون وسعر مقبول جدا.
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.291941374540329
#
#         # Original Example: جيد. طاقم العمل جداً بشوشين ومتعاونين. السرير غير مريح
#           > Predication Label: Fair
#           > Predication Score: 0.2607225179672241
#             * Targeted Word: العمل
#             * Synonym Word: الضيافة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. طاقم الضيافة جداً بشوشين ومتعاونين. السرير غير مريح
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2873043417930603
#
#         # Original Example: ضعيف جداً. . التفكري والاهتمام بالمبلغ قبل النزيل
#           > Predication Label: Fair
#           > Predication Score: 0.275016725063324
#             * Targeted Word: بالمبلغ
#             * Synonym Word: بالآخر
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ضعيف جداً. . التفكري والاهتمام بالآخر قبل النزيل
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2804693579673767
#
#         # Original Example: “عيبة موقعه”. جيد بالنسبة للسعر. موقعة صعب الوصول له من كبار السن
#           > Predication Label: Fair
#           > Predication Score: 0.29180869460105896
#             * Targeted Word: الوصول
#             * Synonym Word: بالنسبة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “عيبة موقعه”. جيد بالنسبة للسعر. موقعة صعب بالنسبة له من كبار السن
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.28867989778518677
#
#         # Original Example: رائع. الحقيقة الفندق متميز بخدماته كافة ونظافته والتسهيلات المقدمة لراحة الحاج او المعتمر والفطور جيد جدا .والغرف وتجهيزاتها مريحة وعصرية ..
#           > Predication Label: Poor
#           > Predication Score: 0.3011236786842346
#             * Targeted Word: جدا
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: رائع. الحقيقة الفندق متميز بخدماته كافة ونظافته والتسهيلات المقدمة لراحة الحاج او المعتمر والفطور جيد . .والغرف وتجهيزاتها مريحة وعصرية ..
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2854529917240143
#
#         # Original Example: “فندق رائع ومريح وافطار جميل”. موقع الفندق بجنب مول الاماراتوالانترنت سريع بالغرف واللوبيوالافطار كان ممتاز. انا حجزت مع اطفال ٢ وكان بالعرض عندهم شقة بغرفه واحدة وطلبت منهم اسرّه للاطفال وعطوني سرير للرضع واحد فقط
#           > Predication Label: Good
#           > Predication Score: 0.2856512665748596
#             * Targeted Word: رائع
#             * Synonym Word: جميل
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فندق جميل ومريح وافطار جميل”. موقع الفندق بجنب مول الاماراتوالانترنت سريع بالغرف واللوبيوالافطار كان ممتاز. انا حجزت مع اطفال ٢ وكان بالعرض عندهم شقة بغرفه واحدة وطلبت منهم اسرّه للاطفال وعطوني سرير للرضع واحد فقط
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.27741366624832153
#
#         # Original Example: “القيمة رائعة بالنسبة لمستوى الفندق”. النظافة 👍القيمة مقابل المال 👍الموقع👍مرتب👍. لايوجد توصيل مجاني للحرم 👎مساحة الغرفة صغيرة جداً 👎فيش الغلاية خلف الكومدينة 👎
#           > Predication Label: Poor
#           > Predication Score: 0.2835777997970581
#             * Targeted Word: لمستوى
#             * Synonym Word: لهذا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “القيمة رائعة بالنسبة لهذا الفندق”. النظافة 👍القيمة مقابل المال 👍الموقع👍مرتب👍. لايوجد توصيل مجاني للحرم 👎مساحة الغرفة صغيرة جداً 👎فيش الغلاية خلف الكومدينة 👎
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.28152427077293396
#
#         # Original Example: استثنائي. موقع الفندق ممتاز وقرب المطاعم. لايتوفر نت في الغرفه الا بمبلغ مالي
#           > Predication Label: Excellent
#           > Predication Score: 0.26624053716659546
#             * Targeted Word: وقرب
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. موقع الفندق ممتاز . المطاعم. لايتوفر نت في الغرفه الا بمبلغ مالي
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.25972485542297363
#
#         # Original Example: “الحمد لله إقامه طيبه فى بلد طيبه”. القرب من الحرمأدب و بساطه الموظفين.
#           > Predication Label: Poor
#           > Predication Score: 0.27980315685272217
#             * Targeted Word: الحرمأدب
#             * Synonym Word: المطار
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الحمد لله إقامه طيبه فى بلد طيبه”. القرب من المطار و بساطه الموظفين.
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.27926918864250183
#
#         # Original Example: مخيب للأمل. . اسعار الالعاب المائيه مبالغ فيه مقارنه مع باقي الشواطئ
#           > Predication Label: Poor
#           > Predication Score: 0.281344473361969
#             * Targeted Word: المائيه
#             * Synonym Word: بها
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مخيب للأمل. . اسعار الالعاب بها مبالغ فيه مقارنه مع باقي الشواطئ
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2736721932888031
#
#         # Original Example: “فندق فلسطين الاميز والاحلى .”. فندق يمتاز بالراحه النفسيه وقربه من الحرم .. كل ما فيه يعجبني
#           > Predication Label: Poor
#           > Predication Score: 0.2547686696052551
#             * Targeted Word: النفسيه
#             * Synonym Word: والهدوء
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فندق فلسطين الاميز والاحلى .”. فندق يمتاز بالراحه والهدوء وقربه من الحرم .. كل ما فيه يعجبني
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.3019319176673889
#
#         # Original Example: جيد. النظافة ممتاز. الغرف متجاورة وتسمع اصوات الجيران
#           > Predication Label: Poor
#           > Predication Score: 0.2949112057685852
#             * Targeted Word: الغرف
#             * Synonym Word: البيوت
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. النظافة ممتاز. البيوت متجاورة وتسمع اصوات الجيران
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2870405614376068
#
#         # Original Example: “فندق رائع بمعنى الكلمة ولكن الوصول اليه بالسيارة متعب”. نعم. زحمة المواقفطريقة الانتقال بالمصعد من مواقف السيارات الى غرفتي بالفندق متعبة قليلاَ
#           > Predication Label: Excellent
#           > Predication Score: 0.27263572812080383
#             * Targeted Word: بمعنى
#             * Synonym Word: بهذه
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فندق رائع بهذه الكلمة ولكن الوصول اليه بالسيارة متعب”. نعم. زحمة المواقفطريقة الانتقال بالمصعد من مواقف السيارات الى غرفتي بالفندق متعبة قليلاَ
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2713157832622528
#
#         # Original Example: “رائع”. سعة الغرفة ممتازة. أعمال الصيانة والمضادات
#           > Predication Label: Fair
#           > Predication Score: 0.2756692171096802
#             * Targeted Word: سعة
#             * Synonym Word: خدمات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “رائع”. خدمات الغرفة ممتازة. أعمال الصيانة والمضادات
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2977905571460724
#
#         # Original Example: استثنائي. احترامهم الشديد بالعميل لدرجة اتصلوا علي بعد ما سويت شيك اوت يسألني عن رأيي بالخدمة.
#           > Predication Label: Poor
#           > Predication Score: 0.2851813733577728
#             * Targeted Word: علي
#             * Synonym Word: على
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. احترامهم الشديد بالعميل لدرجة اتصلوا على بعد ما سويت شيك اوت يسألني عن رأيي بالخدمة.
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2849201560020447
#
#         # Original Example: استثنائي. المكان مريح وراقي وسعر مناااسب.
#           > Predication Label: Poor
#           > Predication Score: 0.27615243196487427
#             * Targeted Word: مريح
#             * Synonym Word: رائع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. المكان رائع وراقي وسعر مناااسب.
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.3145969808101654
#
#         # Original Example: جيد. نوعآ ما الراحه. الانترنت ليس بالمجان
#           > Predication Label: Poor
#           > Predication Score: 0.2823336720466614
#             * Targeted Word: نوعآ
#             * Synonym Word: نوعا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. نوعا ما الراحه. الانترنت ليس بالمجان
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.29774877429008484
#
#         # Original Example: “جيد جدا”. كل شي كان رائع وساعاود الحجز فيه مستقبلا. الغرف صغيرة جدا
#           > Predication Label: Excellent
#           > Predication Score: 0.3087940216064453
#             * Targeted Word: رائع
#             * Synonym Word: جيد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيد جدا”. كل شي كان جيد وساعاود الحجز فيه مستقبلا. الغرف صغيرة جدا
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.3036373257637024
#
#         # Original Example: مخيب للأمل. . خذو مني زياده ١٠٠ريال سعودي استغربت انا حاجز عن طريقكم وزياده اول مره تصير معي
#           > Predication Label: Poor
#           > Predication Score: 0.2879372239112854
#             * Targeted Word: خذو
#             * Synonym Word: طالبين
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مخيب للأمل. . طالبين مني زياده ١٠٠ريال سعودي استغربت انا حاجز عن طريقكم وزياده اول مره تصير معي
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2887977063655853
#
#         # Original Example: “اوصي به وبشده”. الفندق عامة ممتااااز. مشوار طويل نوعا ما الى الميترو
#           > Predication Label: Fair
#           > Predication Score: 0.30094969272613525
#             * Targeted Word: نوعا
#             * Synonym Word: اذا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “اوصي به وبشده”. الفندق عامة ممتااااز. مشوار طويل اذا ما الى الميترو
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.28573641180992126
#
#         # Original Example: “الفندق جيد جدا”. الفندق جميل ولكن لا توجد الكثير من المميزات المجانيه.
#           > Predication Label: Fair
#           > Predication Score: 0.2945272624492645
#             * Targeted Word: توجد
#             * Synonym Word: يوجد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الفندق جيد جدا”. الفندق جميل ولكن لا يوجد الكثير من المميزات المجانيه.
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2941100299358368
#
#         # Original Example: “ممتاز”. 1- النظافة2- الهدوء3- المواقف مجانية 4- الانترنت مجانا. لاشئ
#           > Predication Label: Poor
#           > Predication Score: 0.2868331968784332
#             * Targeted Word: مجانية
#             * Synonym Word: الخضراء
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ممتاز”. 1- النظافة2- الهدوء3- المواقف الخضراء 4- الانترنت مجانا. لاشئ
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.27987104654312134
#
#         # Original Example: مخيب للأمل. عادي. أسلوب الرسبشن وتاخير في تسجيل الدخول
#           > Predication Label: Poor
#           > Predication Score: 0.29105448722839355
#             * Targeted Word: الرسبشن
#             * Synonym Word: جديد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مخيب للأمل. عادي. أسلوب جديد وتاخير في تسجيل الدخول
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2765696048736572
#
#         # Original Example: “Mhhotail”. الموقع. الخدمه تعامل العاملين.
#           > Predication Label: Fair
#           > Predication Score: 0.28964200615882874
#             * Targeted Word: الخدمه
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “Mhhotail”. الموقع. . تعامل العاملين.
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2911922335624695
#
#         # Original Example: مخيب للأمل. فقط السعر. الاسرار غير نظيفه جدا والنت وقت كويس ووقت سيء موقعه كانك بالغرابي علشان محد ينخدع
#           > Predication Label: Poor
#           > Predication Score: 0.29411399364471436
#             * Targeted Word: مخيب
#             * Synonym Word: فاقد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: فاقد للأمل. فقط السعر. الاسرار غير نظيفه جدا والنت وقت كويس ووقت سيء موقعه كانك بالغرابي علشان محد ينخدع
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.29614269733428955
#
#         # Original Example: “إبــــــداع التعامل والرقي”. المسبح وكذلك المطعم والنادي الرياضي. لاشي
#           > Predication Label: Fair
#           > Predication Score: 0.2837466597557068
#             * Targeted Word: المطعم
#             * Synonym Word: النادي
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “إبــــــداع التعامل والرقي”. المسبح وكذلك النادي والنادي الرياضي. لاشي
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.28461551666259766
#
#         # Original Example: “متميِّزين في الخدمات”. الإفطار لذيذ. لايوجد
#           > Predication Label: Fair
#           > Predication Score: 0.2756692171096802
#             * Targeted Word: الإفطار
#             * Synonym Word: الطعام
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “متميِّزين في الخدمات”. الطعام لذيذ. لايوجد
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.28723910450935364
#
#         # Original Example: “جدا سيئ”. لا شي مريح. ضيق الغرفه والاستقبال في الفندق خصوصا المدير المناوب اليلي
#           > Predication Label: Fair
#           > Predication Score: 0.2941209077835083
#             * Targeted Word: الغرفه
#             * Synonym Word: الموظفين
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جدا سيئ”. لا شي مريح. ضيق الموظفين والاستقبال في الفندق خصوصا المدير المناوب اليلي
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.28017255663871765
#
#         # Original Example: استثنائي. . أزعجني عندما طلبت تمديد إقامتي رفضوا ولم يبلغوني او سوالي عن إمكانية التمديد
#           > Predication Label: Fair
#           > Predication Score: 0.2864558696746826
#             * Targeted Word: ولم
#             * Synonym Word: ان
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. . أزعجني عندما طلبت تمديد إقامتي رفضوا ان يبلغوني او سوالي عن إمكانية التمديد
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.2890162765979767
#
#         # Original Example: “لا انصح بالشباب للنزول في الفندق”. الموقع. خدمة وتعامل ولا يقبل زوار وإزعاج ازعاج
#           > Predication Label: Poor
#           > Predication Score: 0.27628594636917114
#             * Targeted Word: وإزعاج
#             * Synonym Word: او
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “لا انصح بالشباب للنزول في الفندق”. الموقع. خدمة وتعامل ولا يقبل زوار او ازعاج
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2902319133281708
#
#    ## Attack Results:
#         # Model: CNN
#         # Dataset: HARD
#           > Accuracy Before Attack (via Truth Labels): 27.0 %
#           > Accuracy Before Attack (via Predication Scores): 28.84 %
#           < Accuracy After Attack (via Predication Labels): 41.0 %
#           < Accuracy After Attack (via Predication Scores): 28.42 %
#
#
# CPU times: user 2h 40min 9s, sys: 9min 48s, total: 2h 49min 58s
# Wall time: 2h 55min 9s

# %%
# %%time

from bert_attack import *

min_length = 30
max_length = 300
number_examples = 100

models = ['cnn']
datasets = ['msda']

main(models, datasets, min_length, max_length, number_examples)
# Out:
# @@@ BEGINNING ATTACK: [ MODEL: `CNN` | DATASET: `MSDA` ] @@@
#
#    ## Sampling Examples from `MSDA` Dataset:
#       # Total Number of Qualified Examples: 17,424
#       # Total Number of Randomly Selected Examples: 100
#
#    ## Running BERT Synonym-level Attack on `CNN` Model:
#         # Original Example: تهنيتي منو هههههه لي مايعرفش ديمقراطية ويفضل يقسم لبلاد مايتسماش ولد بلاد وحدة مدام هو اصلا مش داير لعرب ولاد بلاده
#           > Predication Label: Negative
#           > Predication Score: 0.4103591740131378
#             * Targeted Word: مش
#             * Synonym Word: كان
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: تهنيتي منو هههههه لي مايعرفش ديمقراطية ويفضل يقسم لبلاد مايتسماش ولد بلاد وحدة مدام هو اصلا كان داير لعرب ولاد بلاده
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3835473358631134
#
#         # Original Example: : كلنا ثقه في قيادتنا ونؤيدها وخلفها بقوة 💪💪💪 تحيا_مصر_السيسي تحيا_مصر_وعاش_السيسي ✌️ 🇪🇬🇪🇬🇪🇬
#           > Predication Label: Neutral
#           > Predication Score: 0.3907277584075928
#             * Targeted Word: قيادتنا
#             * Synonym Word: دولتنا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : كلنا ثقه في دولتنا ونؤيدها وخلفها بقوة 💪💪💪 تحيا_مصر_السيسي تحيا_مصر_وعاش_السيسي ✌️ 🇪🇬🇪🇬🇪🇬
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.37896668910980225
#
#         # Original Example: مصدرمة بجد مش بنطق و على عايزة أرد 😟 بصوت اليسا جيشنا_فخرنا الجزائر
#           > Predication Label: Neutral
#           > Predication Score: 0.4127391278743744
#             * Targeted Word: اليسا
#             * Synonym Word: عال
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مصدرمة بجد مش بنطق و على عايزة أرد 😟 بصوت عال جيشنا_فخرنا الجزائر
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.38921692967414856
#
#         # Original Example: إلاهي وانت جاهي أرنا عجائب قدرتك في هاته الجارية 👐 مثلما رأينا تلك التي قالت يحيا بوتبون تعاني وتبكي حسرتها سنراكي انت أيضا يوما ما وليس ببعيد عنكم يا بوصبع زرق منتن مزنجر 👌💦☝ كلنا_تينزاوتين هدفنا_واحد_يتنحاو_ڨاع
#           > Predication Label: Neutral
#           > Predication Score: 0.388497531414032
#             * Targeted Word: زرق
#             * Synonym Word: و
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: إلاهي وانت جاهي أرنا عجائب قدرتك في هاته الجارية 👐 مثلما رأينا تلك التي قالت يحيا بوتبون تعاني وتبكي حسرتها سنراكي انت أيضا يوما ما وليس ببعيد عنكم يا بوصبع و منتن مزنجر 👌💦☝ كلنا_تينزاوتين هدفنا_واحد_يتنحاو_ڨاع
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.3954406678676605
#
#         # Original Example: معلوماتي بكرة السلة على قديّ بس شايفة منتخب لبنان عم يلعب روعة ! صحّ؟؟
#           > Predication Label: Negative
#           > Predication Score: 0.39778709411621094
#             * Targeted Word: منتخب
#             * Synonym Word: أن
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: معلوماتي بكرة السلة على قديّ بس شايفة أن لبنان عم يلعب روعة ! صحّ؟؟
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.4173171818256378
#
#         # Original Example: نعم و بفضلها بو☝ مش مستحمر برك راهو مستفرن مستمعز مستدوب وكل صفات الحيوانات راهي فيه مع احتراماتنا للحيوانات طبعا 👌😤 حراك_شعبي_ماشي_ايديولوجي توقفوا_عن_استدعاء_النشطاء
#           > Predication Label: Neutral
#           > Predication Score: 0.3955065906047821
#             * Targeted Word: حراك_شعبي_ماشي_ايديولوجي
#             * Synonym Word: -
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: نعم و بفضلها بو☝ مش مستحمر برك راهو مستفرن مستمعز مستدوب وكل صفات الحيوانات راهي فيه مع احتراماتنا للحيوانات طبعا 👌😤 - توقفوا_عن_استدعاء_النشطاء
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.38233935832977295
#
#         # Original Example: : محافظ بيروت الذي تم فرض تعيينه لحسابات طائفية ضيقة لم يجد حرجاً في الاحتفاء بالأمر من خلال ركوبه وزوجته على الاكتاف. هل…
#           > Predication Label: Negative
#           > Predication Score: 0.4082476794719696
#             * Targeted Word: خلال
#             * Synonym Word: دون
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : محافظ بيروت الذي تم فرض تعيينه لحسابات طائفية ضيقة لم يجد حرجاً في الاحتفاء بالأمر من دون ركوبه وزوجته على الاكتاف. هل…
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3983810842037201
#
#         # Original Example: بحب احضر نشرتك الاقتصادية(ع قد ما بفهم اقتصاد) لانك الوحيد اللي بتحكي اسرع مني 😂❤️
#           > Predication Label: Negative
#           > Predication Score: 0.41228777170181274
#             * Targeted Word: بفهم
#             * Synonym Word: بدي
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: بحب احضر نشرتك الاقتصادية(ع قد ما بدي اقتصاد) لانك الوحيد اللي بتحكي اسرع مني 😂❤️
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.4488586485385895
#
#         # Original Example: مثل ما اتبنى المسجد الاعظم على كبد فرنسا و اوجاغه دائمة فطريق الحرير سيخترق قلبها
#           > Predication Label: Negative
#           > Predication Score: 0.382215678691864
#             * Targeted Word: المسجد
#             * Synonym Word: الهيكل
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مثل ما اتبنى الهيكل الاعظم على كبد فرنسا و اوجاغه دائمة فطريق الحرير سيخترق قلبها
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.38990452885627747
#
#         # Original Example: : وجهه نظر حضرتك صح برضه وفي ظل الاداء المحترم المعلوماتي والتنفيذي علي ارض الواقع مفيش حاجه مستبعده.
#           > Predication Label: Negative
#           > Predication Score: 0.4010431468486786
#             * Targeted Word: المحترم
#             * Synonym Word: الجيد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : وجهه نظر حضرتك صح برضه وفي ظل الاداء الجيد المعلوماتي والتنفيذي علي ارض الواقع مفيش حاجه مستبعده.
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.38097649812698364
#
#         # Original Example: : البيت الأبيض: ترامب وماكرون يؤكدان ضرورة وقف إطلاق النار في ليبيا بشكل عاجل
#           > Predication Label: Neutral
#           > Predication Score: 0.40154770016670227
#             * Targeted Word: إطلاق
#             * Synonym Word: اطلاق
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : البيت الأبيض: ترامب وماكرون يؤكدان ضرورة وقف اطلاق النار في ليبيا بشكل عاجل
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.41773054003715515
#
#         # Original Example: مساء الخير في قلوبه مرض و العياذ بالله
#           > Predication Label: Neutral
#           > Predication Score: 0.43015220761299133
#             * Targeted Word: قلوبه
#             * Synonym Word: الناس
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مساء الخير في الناس مرض و العياذ بالله
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.4196794033050537
#
#         # Original Example: ربي يرحمه برحمته الواسعة ذكراك في القلب عمي صالح
#           > Predication Label: Neutral
#           > Predication Score: 0.4476071000099182
#             * Targeted Word: الواسعة
#             * Synonym Word: تظل
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ربي يرحمه برحمته تظل ذكراك في القلب عمي صالح
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.3876732289791107
#
#         # Original Example: : عندما يجتمع اهل العزم واهل الوفا. الله يعزك يا مملكة الخير ويحميك يادولة الرئيس.
#           > Predication Label: Negative
#           > Predication Score: 0.4275916814804077
#             * Targeted Word: العزم
#             * Synonym Word: الكرم
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : عندما يجتمع اهل الكرم واهل الوفا. الله يعزك يا مملكة الخير ويحميك يادولة الرئيس.
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.42863649129867554
#
#         # Original Example: : الحاج رابح_درياسة الله يطول عمره 😍 الجزائر
#           > Predication Label: Negative
#           > Predication Score: 0.38137000799179077
#             * Targeted Word: الحاج
#             * Synonym Word: [UNK]
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : [UNK] رابح_درياسة الله يطول عمره 😍 الجزائر
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.38295310735702515
#
#         # Original Example: لم يتجاهل هو تم مناداته ولف موقف عادي يعني لكن انتم متعودين على افلام وحوارات والفتنة متأصلة فيكم ماشاءالله واعتقد شيءلا يدعو لا للضحك ولا للسخرية انت اساسا مسخرة بتنزيلك.تويتة.مثل هاذي
#           > Predication Label: Negative
#           > Predication Score: 0.38066133856773376
#             * Targeted Word: افلام
#             * Synonym Word: نقاشات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: لم يتجاهل هو تم مناداته ولف موقف عادي يعني لكن انتم متعودين على نقاشات وحوارات والفتنة متأصلة فيكم ماشاءالله واعتقد شيءلا يدعو لا للضحك ولا للسخرية انت اساسا مسخرة بتنزيلك.تويتة.مثل هاذي
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3803199827671051
#
#         # Original Example: غالبا غايديرو الحجر تا افوت رمضان و الله أعلم
#           > Predication Label: Neutral
#           > Predication Score: 0.3815609812736511
#             * Targeted Word: تا
#             * Synonym Word: باش
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: غالبا غايديرو الحجر باش افوت رمضان و الله أعلم
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.3787982165813446
#
#         # Original Example: : يقال ان خلاص خلصت ودخلوا طرابلس والسراج هرب لمالطه
#           > Predication Label: Negative
#           > Predication Score: 0.42070090770721436
#             * Targeted Word: خلاص
#             * Synonym Word: السنة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : يقال ان السنة خلصت ودخلوا طرابلس والسراج هرب لمالطه
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3966497778892517
#
#         # Original Example: برضو هاني ..تطلب من ربنا ..مش تطلع النت ...يا جماعة كل واحد وتفكيره بءا ..وتربيته..ومبادي وعادات ..
#           > Predication Label: Neutral
#           > Predication Score: 0.42782434821128845
#             * Targeted Word: ربنا
#             * Synonym Word: الناس
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: برضو هاني ..تطلب من الناس ..مش تطلع النت ...يا جماعة كل واحد وتفكيره بءا ..وتربيته..ومبادي وعادات ..
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.39268654584884644
#
#         # Original Example: ملي رجعو الجلسة غدا عوض نهار الخميس را باين البلان ... غا لي مبغاش افهم نتسناو واحد 20 يوم اخرى 😭😭
#           > Predication Label: Neutral
#           > Predication Score: 0.4202309250831604
#             * Targeted Word: الجلسة
#             * Synonym Word: الى
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ملي رجعو الى غدا عوض نهار الخميس را باين البلان ... غا لي مبغاش افهم نتسناو واحد 20 يوم اخرى 😭😭
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.3979276716709137
#
#         # Original Example: تشييع الشهيد فواز فؤاد السمان في ساحة النور بعد قليل طرابلس
#           > Predication Label: Neutral
#           > Predication Score: 0.4005618393421173
#             * Targeted Word: تشييع
#             * Synonym Word: معرض
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: معرض الشهيد فواز فؤاد السمان في ساحة النور بعد قليل طرابلس
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.46587681770324707
#
#         # Original Example: : الله يوفقك ي غالي 💙 وشكرا كتيير على اللقاء الرائع والصادق شكرا من كل قلبنا 😄
#           > Predication Label: Negative
#           > Predication Score: 0.3912133574485779
#             * Targeted Word: الله
#             * Synonym Word: والله
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : والله يوفقك ي غالي 💙 وشكرا كتيير على اللقاء الرائع والصادق شكرا من كل قلبنا 😄
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.37726131081581116
#
#         # Original Example: كمية الطلعات والنزلات اللي بيقطع فيها مزاجي خلال اليوم بدون ولا اي سبب هي اكتر شي مزعج بالحياة.
#           > Predication Label: Neutral
#           > Predication Score: 0.39810076355934143
#             * Targeted Word: اليوم
#             * Synonym Word: العام
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: كمية الطلعات والنزلات اللي بيقطع فيها مزاجي خلال العام بدون ولا اي سبب هي اكتر شي مزعج بالحياة.
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.3865974247455597
#
#         # Original Example: انت بكل مكان لو سمحت بعدين انا صليت ما استناك 🤬
#           > Predication Label: Neutral
#           > Predication Score: 0.40577682852745056
#             * Targeted Word: صليت
#             * Synonym Word: بحبك
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: انت بكل مكان لو سمحت بعدين انا بحبك ما استناك 🤬
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.38210684061050415
#
#         # Original Example: : تسجيل 10 إصابات جديدة بفيروس كورونا في لبنان ليبلغ مجموع الإصابات 619
#           > Predication Label: Negative
#           > Predication Score: 0.5101062059402466
#             * Targeted Word: لبنان
#             * Synonym Word: جدة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : تسجيل 10 إصابات جديدة بفيروس كورونا في جدة ليبلغ مجموع الإصابات 619
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.45947593450546265
#
#    ## Attack Results:
#         # Model: CNN
#         # Dataset: MSDA
#           > Accuracy Before Attack (via Truth Labels): 59.0 %
#           > Accuracy Before Attack (via Predication Scores): 45.91 %
#           < Accuracy After Attack (via Predication Labels): 75.0 %
#           < Accuracy After Attack (via Predication Scores): 40.08 %
#
#
# CPU times: user 2h 45min 43s, sys: 10min 42s, total: 2h 56min 25s
# Wall time: 2h 59min 58s
