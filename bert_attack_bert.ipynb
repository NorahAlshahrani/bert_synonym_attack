# %%
# %%time

from bert_attack import *

min_length = 30
max_length = 300
number_examples = 100

datasets = ['hard', 'msda']
models = [ 'bert']#, 'cnn', 'bilstm']

main(models, datasets, min_length, max_length, number_examples)
# Out:
# @@@ BEGINNING ATTACK: [ MODEL: `BERT` | DATASET: `HARD` ] @@@
#
#    ## Sampling Examples from `HARD` Dataset:
#       # Total Number of Qualified Examples: 44,804
#       # Total Number of Randomly Selected Examples: 100
#
#    ## Running BERT Synonym-level Attack on `BERT` Model:
#         # Original Example: “فندق عالمي”. الموقع والتعامل الراقي وتنوع الافطار. كل شي في هذا الفندق رائع. المخدات غير مريحه
#           > Predication Label: Excellent
#           > Predication Score: 0.754844069480896
#             * Targeted Word: المخدات
#             * Synonym Word: الاقامة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فندق عالمي”. الموقع والتعامل الراقي وتنوع الافطار. كل شي في هذا الفندق رائع. الاقامة غير مريحه
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.6298982501029968
#
#         # Original Example: “ترفيه”. موقع الفندق. الاثاث قديم ولا يوجد راحه الصور عكس الواقع
#           > Predication Label: Fair
#           > Predication Score: 0.9434990882873535
#             * Targeted Word: راحه
#             * Synonym Word: حمامات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ترفيه”. موقع الفندق. الاثاث قديم ولا يوجد حمامات الصور عكس الواقع
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.5524219274520874
#
#         # Original Example: “انبسطت بالنايت كلوب”. كل شي. المسبح بالدور ٤٨ هواء شديد ما استمتعت بالسباحة
#           > Predication Label: Excellent
#           > Predication Score: 0.5148939490318298
#             * Targeted Word: هواء
#             * Synonym Word: للاسف
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “انبسطت بالنايت كلوب”. كل شي. المسبح بالدور ٤٨ للاسف شديد ما استمتعت بالسباحة
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.5808800458908081
#
#         # Original Example: “الدمام”. متى كانت العروض والخدمه ممتازه كنا السباقون لكم. لاشي
#           > Predication Label: Good
#           > Predication Score: 0.627056896686554
#             * Targeted Word: السباقون
#             * Synonym Word: قدمنا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الدمام”. متى كانت العروض والخدمه ممتازه كنا قدمنا لكم. لاشي
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.5564194321632385
#
#         # Original Example: “مريح وجميل وفطور لذيذ ،”. راحة السرير . طاقم العمل
#           > Predication Label: Excellent
#           > Predication Score: 0.6150213479995728
#             * Targeted Word: وجميل
#             * Synonym Word: ،
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “مريح ، وفطور لذيذ ،”. راحة السرير . طاقم العمل
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.5485596656799316
#
#         # Original Example: “تجربه الفندق اول مره”. . النظافة معدومه في الغرفة والحمام بشكل عام
#           > Predication Label: Fair
#           > Predication Score: 0.5225503444671631
#             * Targeted Word: النظافة
#             * Synonym Word: كانت
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “تجربه الفندق اول مره”. . كانت معدومه في الغرفة والحمام بشكل عام
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.7170799970626831
#
#         # Original Example: “غير جيد”. لا يوجد شي جيد. الاستقبال سيء ..النت غير مجاني ..المواقف قليلة ..
#           > Predication Label: Poor
#           > Predication Score: 0.7391436696052551
#             * Targeted Word: سيء
#             * Synonym Word: قليل
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “غير جيد”. لا يوجد شي جيد. الاستقبال قليل ..النت غير مجاني ..المواقف قليلة ..
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.5607953071594238
#
#         # Original Example: “جناح بجانب الحرم”. الافطار جيد ومتنوعوالمكان قريب من الحرموتم منحى جناح!.
#           > Predication Label: Good
#           > Predication Score: 0.8551141023635864
#             * Targeted Word: جيد
#             * Synonym Word: متنوع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جناح بجانب الحرم”. الافطار متنوع ومتنوعوالمكان قريب من الحرموتم منحى جناح!.
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.5435945391654968
#
#         # Original Example: “ممتازه”. الفندق رهيب وكل شي فيه ممتاز. الغساله خربانه
#           > Predication Label: Excellent
#           > Predication Score: 0.5675470232963562
#             * Targeted Word: وكل
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ممتازه”. الفندق رهيب . شي فيه ممتاز. الغساله خربانه
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.5577794313430786
#
#         # Original Example: “جيد جدا لاباس به”. المكان هادئ وجميل. الموقع بعيد عن وسط مدينة جدة لاتوجد ملظات للسيارات المواقف قليلة جداوجدت منشفة غير نظيفة توجد مشكلة تصريف مياه الاستحمام
#           > Predication Label: Fair
#           > Predication Score: 0.8207980990409851
#             * Targeted Word: لاباس
#             * Synonym Word: أنصح
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيد جدا أنصح به”. المكان هادئ وجميل. الموقع بعيد عن وسط مدينة جدة لاتوجد ملظات للسيارات المواقف قليلة جداوجدت منشفة غير نظيفة توجد مشكلة تصريف مياه الاستحمام
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.7549710869789124
#
#         # Original Example: “الان”. اوكي نوعا ما بسب قربه من المطار. لاشئ
#           > Predication Label: Good
#           > Predication Score: 0.6460257768630981
#             * Targeted Word: بسب
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الان”. اوكي نوعا ما . قربه من المطار. لاشئ
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.604593813419342
#
#         # Original Example: جيد جداً. النظافه وقربه من المترو.. وجود بار مقابل الفندق.الاثاث قديم قليلا.
#           > Predication Label: Good
#           > Predication Score: 0.9989739656448364
#             * Targeted Word: جيد
#             * Synonym Word: ممتاز
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ممتاز جداً. النظافه وقربه من المترو.. وجود بار مقابل الفندق.الاثاث قديم قليلا.
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.9958283305168152
#
#         # Original Example: مخيب للأمل. . السعر مختلف عن البوكنق
#           > Predication Label: Fair
#           > Predication Score: 0.999110758304596
#             * Targeted Word: مخيب
#             * Synonym Word: منجم
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: منجم للأمل. . السعر مختلف عن البوكنق
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.40610960125923157
#
#         # Original Example: “جيد جداً”. كل شي جميل ، والاجمل اني كنت حاجز غرفه عاديه وعطوني سويت بنفس السعر ،الفندق كبير وحلو وسعره مناسب . لاشئ يستحق الذكر
#           > Predication Label: Good
#           > Predication Score: 0.5596860647201538
#             * Targeted Word: والاجمل
#             * Synonym Word: اذكر
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيد جداً”. كل شي جميل ، اذكر اني كنت حاجز غرفه عاديه وعطوني سويت بنفس السعر ،الفندق كبير وحلو وسعره مناسب . لاشئ يستحق الذكر
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.502622663974762
#
#         # Original Example: “ابو ريتاج”. النظافه. بعده عن الحرملايوجد خدمات قريبهالغرفه والاسره صغيره ازعاج عمال النظافه في الممراتفي رمضان لا يوجد الا باص واحد فقط
#           > Predication Label: Fair
#           > Predication Score: 0.6138255596160889
#             * Targeted Word: رمضان
#             * Synonym Word: الممرات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ابو ريتاج”. النظافه. بعده عن الحرملايوجد خدمات قريبهالغرفه والاسره صغيره ازعاج عمال النظافه في الممراتفي الممرات لا يوجد الا باص واحد فقط
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.508677065372467
#
#         # Original Example: “سعر اﻻستقبال اقل من بوكين بخمسه بالمائه معقول”. ﻻشيئ. الخدمات /اﻻستقبال/ المراتب لها اصوات / الكوفي يقفل بدري وﻻ تؤمن الخدمة باﻻتصال بالهاتف .
#           > Predication Label: Good
#           > Predication Score: 0.6145880222320557
#             * Targeted Word: الخدمات
#             * Synonym Word: [UNK]
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “سعر اﻻستقبال اقل من بوكين بخمسه بالمائه معقول”. ﻻشيئ. [UNK] /اﻻستقبال/ المراتب لها اصوات / الكوفي يقفل بدري وﻻ تؤمن الخدمة باﻻتصال بالهاتف .
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.5780852437019348
#
#         # Original Example: “سأسكن فيه مرة أخرى إن شاء الله .”. الافطار متنوع - قربه من الحرم. لا شئ
#           > Predication Label: Excellent
#           > Predication Score: 0.5672898292541504
#             * Targeted Word: أخرى
#             * Synonym Word: واحدة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “سأسكن فيه مرة واحدة إن شاء الله .”. الافطار متنوع - قربه من الحرم. لا شئ
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.5506600141525269
#
#         # Original Example: “فندق رائع”. اﻹستقبال رائع و الموظفين ودودين. التأخر في خدمة تنظيف الغرف
#           > Predication Label: Excellent
#           > Predication Score: 0.5766669511795044
#             * Targeted Word: تنظيف
#             * Synonym Word: خدمة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فندق رائع”. اﻹستقبال رائع و الموظفين ودودين. التأخر في خدمة خدمة الغرف
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.6158183217048645
#
#         # Original Example: “لاتغيرك الصور للفندق هذا فقط المدخل اما في الرده سيى”. . موقع الغرفه و الرئحه المقرفه فيه
#           > Predication Label: Fair
#           > Predication Score: 0.7051456570625305
#             * Targeted Word: الرده
#             * Synonym Word: ال
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “لاتغيرك الصور للفندق هذا فقط المدخل اما في ال سيى”. . موقع الغرفه و الرئحه المقرفه فيه
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.6974225044250488
#
#         # Original Example: “انصح به”. تعاون الموظفين وموقع الفندق وسرعة الاستجابة. المياه كانت ضعيفة نوعا ما في الحمام
#           > Predication Label: Excellent
#           > Predication Score: 0.5606568455696106
#             * Targeted Word: وموقع
#             * Synonym Word: في
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “انصح به”. تعاون الموظفين في الفندق وسرعة الاستجابة. المياه كانت ضعيفة نوعا ما في الحمام
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.5948324799537659
#
#         # Original Example: “الهدوء والبعد عن صخب المدينة”. الراحة والهدوء ،اجواء شرق آسوية جميله. كثرة اعشاب البحر وصعوبة السباحة في  لوجود كائنات بحرية مؤذية
#           > Predication Label: Good
#           > Predication Score: 0.8690828680992126
#             * Targeted Word: مؤذية
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الهدوء والبعد عن صخب المدينة”. الراحة والهدوء ،اجواء شرق آسوية جميله. كثرة اعشاب البحر وصعوبة السباحة في لوجود كائنات بحرية .
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.630715548992157
#
#         # Original Example: “ليلة رائعه من الاستجماع”. اعجبني رائحة الفندق الزهية والسرير كان رائع مرييح.
#           > Predication Label: Excellent
#           > Predication Score: 0.8512173295021057
#             * Targeted Word: رائعه
#             * Synonym Word: جيدة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ليلة جيدة من الاستجماع”. اعجبني رائحة الفندق الزهية والسرير كان رائع مرييح.
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.5807030200958252
#
#         # Original Example: “أسوء فندق”. . طاقم العمل شديدي الإزعاج والاستقبال والضيافة سيئة جدا
#           > Predication Label: Poor
#           > Predication Score: 0.5695094466209412
#             * Targeted Word: والضيافة
#             * Synonym Word: والخدمة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “أسوء فندق”. . طاقم العمل شديدي الإزعاج والاستقبال والخدمة سيئة جدا
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.5127267837524414
#
#         # Original Example: “رحلة عمل لمركز المعارض الدولي”. رائحة كريهة بالمفارش.
#           > Predication Label: Fair
#           > Predication Score: 0.8883089423179626
#             * Targeted Word: رائحة
#             * Synonym Word: أيام
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “رحلة عمل لمركز المعارض الدولي”. أيام كريهة بالمفارش.
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.5048273801803589
#
#         # Original Example: “الروعة”. الاستقبال الجيدالابتسامة والبشاشة في وجوه العاملين. السعر عال
#           > Predication Label: Good
#           > Predication Score: 0.8037320971488953
#             * Targeted Word: السعر
#             * Synonym Word: تعاون
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الروعة”. الاستقبال الجيدالابتسامة والبشاشة في وجوه العاملين. تعاون عال
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.5308258533477783
#
#    ## Attack Results:
#         # Model: BERT
#         # Dataset: HARD
#           > Accuracy Before Attack (via Truth Labels): 79.0 %
#           > Accuracy Before Attack (via Predication Scores): 88.59 %
#           < Accuracy After Attack (via Predication Labels): 75.0 %
#           < Accuracy After Attack (via Predication Scores): 59.27 %
#
#
# @@@ BEGINNING ATTACK: [ MODEL: `BERT` | DATASET: `MSDA` ] @@@
#
#    ## Sampling Examples from `MSDA` Dataset:
#       # Total Number of Qualified Examples: 17,424
#       # Total Number of Randomly Selected Examples: 100
#
#    ## Running BERT Synonym-level Attack on `BERT` Model:
#         # Original Example: الطريق مقفل بسبب صيانة الوطن لبنان_يثور لبنان__ينتفض كلن_يعني_كلن
#           > Predication Label: Negative
#           > Predication Score: 0.9154908657073975
#             * Targeted Word: بسبب
#             * Synonym Word: الى
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: الطريق مقفل الى صيانة الوطن لبنان_يثور لبنان__ينتفض كلن_يعني_كلن
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.5851753950119019
#
#         # Original Example: : "لم تكن كل الطرق تؤدي إليك، أنا من كان يعكف الطريق عنوةً ليعود إليك."
#           > Predication Label: Negative
#           > Predication Score: 0.8279703259468079
#             * Targeted Word: تؤدي
#             * Synonym Word: لتصل
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : "لم تكن كل الطرق لتصل إليك، أنا من كان يعكف الطريق عنوةً ليعود إليك."
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.448905348777771
#
#         # Original Example: لبنان.. وثيقة "منع اللاجئين الفلسطينيين" تثير غضبا واسعا ... لبنان
#           > Predication Label: Negative
#           > Predication Score: 0.6656882762908936
#             * Targeted Word: وثيقة
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: لبنان.. . "منع اللاجئين الفلسطينيين" تثير غضبا واسعا ... لبنان
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.5268101096153259
#
#         # Original Example: : الف سلامات علي قلبك انت العسل بكلك 🌹
#           > Predication Label: Positive
#           > Predication Score: 0.780446469783783
#             * Targeted Word: علي
#             * Synonym Word: على
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : الف سلامات على قلبك انت العسل بكلك 🌹
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.6917210817337036
#
#         # Original Example: معك حقّ يمنى. الحاجات الاساسية عم تنسينا انو الولد بحاجة كمان يفرح. لازم نفكر فيهن 😍
#           > Predication Label: Negative
#           > Predication Score: 0.70564866065979
#             * Targeted Word: عم
#             * Synonym Word: لا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: معك حقّ يمنى. الحاجات الاساسية لا تنسينا انو الولد بحاجة كمان يفرح. لازم نفكر فيهن 😍
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.7830893397331238
#
#         # Original Example: : انتظر متى يخلص رمضان لأن روتين النوم فيه مؤذي نفسياً وجسدياً ولا يكفي الحاجة
#           > Predication Label: Neutral
#           > Predication Score: 0.8202809691429138
#             * Targeted Word: نفسياً
#             * Synonym Word: [
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : انتظر متى يخلص رمضان لأن روتين النوم فيه مؤذي [ وجسدياً ولا يكفي الحاجة
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.7463264465332031
#
#         # Original Example: كمية الجلقان ع امي بس امرض بتخليها تندم انها مضطرة تكون نبع الحنان
#           > Predication Label: Negative
#           > Predication Score: 0.9602810144424438
#             * Targeted Word: بتخليها
#             * Synonym Word: لازم
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: كمية الجلقان ع امي بس امرض لازم تندم انها مضطرة تكون نبع الحنان
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.45354554057121277
#
#         # Original Example: كلنا نفس الصوت ....نحن من انتخبوا وجنبنا الوطن ويلات الخونة يجي درك يعطوهم الاحقية في كل شي لا
#           > Predication Label: Negative
#           > Predication Score: 0.49322476983070374
#             * Targeted Word: الخونة
#             * Synonym Word: الانتخابات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: كلنا نفس الصوت ....نحن من انتخبوا وجنبنا الوطن ويلات الانتخابات يجي درك يعطوهم الاحقية في كل شي لا
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.5556713938713074
#
#         # Original Example: عندنا ف عائلة بنات و وولاد كلهم كياخدو نفس المبلغ مكيناش ديك لعبة حقا بنت ولا ولد حشومة
#           > Predication Label: Negative
#           > Predication Score: 0.6673968434333801
#             * Targeted Word: بنات
#             * Synonym Word: بنت
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: عندنا ف عائلة بنت و وولاد كلهم كياخدو نفس المبلغ مكيناش ديك لعبة حقا بنت ولا ولد حشومة
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.6707015037536621
#
#         # Original Example: : مش لو لقي رمله نفسي أشوف شكله الحرامي دلوقتي
#           > Predication Label: Negative
#           > Predication Score: 0.49339354038238525
#             * Targeted Word: شكله
#             * Synonym Word: وجه
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : مش لو لقي رمله نفسي أشوف وجه الحرامي دلوقتي
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.7745838165283203
#
#         # Original Example: كان بعد في بس أغاني فيروز ما انقسموا اللبنانيين عليها بطّمنكم: مِشي الحال
#           > Predication Label: Neutral
#           > Predication Score: 0.42569294571876526
#             * Targeted Word: مِشي
#             * Synonym Word: كيف
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: كان بعد في بس أغاني فيروز ما انقسموا اللبنانيين عليها بطّمنكم: كيف الحال
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.944337010383606
#
#         # Original Example: بده ينقطع الامل بهاليومين اللي جايين.
#           > Predication Label: Neutral
#           > Predication Score: 0.7821648120880127
#             * Targeted Word: ينقطع
#             * Synonym Word: يزرع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: بده يزرع الامل بهاليومين اللي جايين.
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.8696185946464539
#
#         # Original Example: الشعب يريد حكومة من ٢٠ أمثال ملحم_خلف
#           > Predication Label: Neutral
#           > Predication Score: 0.7178438305854797
#             * Targeted Word: الشعب
#             * Synonym Word: عون
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: عون يريد حكومة من ٢٠ أمثال ملحم_خلف
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.6541033387184143
#
#         # Original Example: : وحدة من احلى واجمل الصور اللي صورتها.. هيدي بيروت يا جماعة ب ١٨ تشرين 2019 ٦_اشهر_من_الثورة
#           > Predication Label: Negative
#           > Predication Score: 0.7340397834777832
#             * Targeted Word: جماعة
#             * Synonym Word: سوريا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : وحدة من احلى واجمل الصور اللي صورتها.. هيدي بيروت يا سوريا ب ١٨ تشرين 2019 ٦_اشهر_من_الثورة
#           < Adversarial Label:  Positive
#           < Adversarial Score:  0.7685145735740662
#
#         # Original Example: : أعياد بيروت 2016: أسماء لبنانية لامعة...ومفاجآت عربية وعالمية - رنا أسطيح
#           > Predication Label: Negative
#           > Predication Score: 0.5658131837844849
#             * Targeted Word: أعياد
#             * Synonym Word: معرض
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : معرض بيروت 2016: أسماء لبنانية لامعة...ومفاجآت عربية وعالمية - رنا أسطيح
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.5653504729270935
#
#         # Original Example: : مين_بيعرف وصل الحلف النسائي الثلاثي عال final الكل شاطرين والارجح جويس رح تربح لانها ممّرنة على كبسة الزر وما بتُقْطُم…
#           > Predication Label: Neutral
#           > Predication Score: 0.8482169508934021
#             * Targeted Word: ممّرنة
#             * Synonym Word: تعودت
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : مين_بيعرف وصل الحلف النسائي الثلاثي عال final الكل شاطرين والارجح جويس رح تربح لانها تعودت على كبسة الزر وما بتُقْطُم…
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.9099947214126587
#
#         # Original Example: اشكال في تعلبايا بين المتظاهرين والقوى الامنية لبنان_ينتفض
#           > Predication Label: Neutral
#           > Predication Score: 0.8986381888389587
#             * Targeted Word: المتظاهرين
#             * Synonym Word: الاهالي
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: اشكال في تعلبايا بين الاهالي والقوى الامنية لبنان_ينتفض
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.7346254587173462
#
#         # Original Example: : شكرا لنصيرة المرأة والصديقة الصادقة ول لانن فكروا فينا ولدعمن الدائم لقضايا المرأة. كل عام وأم…
#           > Predication Label: Positive
#           > Predication Score: 0.8003077507019043
#             * Targeted Word: شكرا
#             * Synonym Word: تحية
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : تحية لنصيرة المرأة والصديقة الصادقة ول لانن فكروا فينا ولدعمن الدائم لقضايا المرأة. كل عام وأم…
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.5578553676605225
#
#         # Original Example: شو صار بالشارع لمّا بنت تعرّضت للإغتصاب؟ مين_الفِلتان؟ what happens to a rape victim when she seeks help on the streets? ابعاد shameonwho minelfelten
#           > Predication Label: Neutral
#           > Predication Score: 0.6223838925361633
#             * Targeted Word: تعرّضت
#             * Synonym Word: تعرضت
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: شو صار بالشارع لمّا بنت تعرضت للإغتصاب؟ مين_الفِلتان؟ what happens to a rape victim when she seeks help on the streets? ابعاد shameonwho minelfelten
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.9746323227882385
#
#         # Original Example: : ليبيا المتحدث باسم الجيش الليبي: إسقاط طائرة تركية مسيرة في عين زارة جنوبي طرابلس .
#           > Predication Label: Negative
#           > Predication Score: 0.6400269865989685
#             * Targeted Word: الجيش
#             * Synonym Word: البرلمان
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : ليبيا المتحدث باسم البرلمان الليبي: إسقاط طائرة تركية مسيرة في عين زارة جنوبي طرابلس .
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.5157038569450378
#
#         # Original Example: اعشق ❤ التشيز كيك مهما تكون الوصفات و تتغير yummy
#           > Predication Label: Positive
#           > Predication Score: 0.5594348907470703
#             * Targeted Word: تتغير
#             * Synonym Word: المقادير
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: اعشق ❤ التشيز كيك مهما تكون الوصفات و المقادير yummy
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.5221063494682312
#
#         # Original Example: بنت خالتي كتعرف دوي بدريجة ولكن مكتعرفش تقرا العربية حيت عمرها قراتها ودابا بغا تولي تصلي وش كاين نسخة من القرآن باللغة الفرنسية
#           > Predication Label: Neutral
#           > Predication Score: 0.7510063648223877
#             * Targeted Word: مكتعرفش
#             * Synonym Word: ما
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: بنت خالتي كتعرف دوي بدريجة ولكن ما تقرا العربية حيت عمرها قراتها ودابا بغا تولي تصلي وش كاين نسخة من القرآن باللغة الفرنسية
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.6214560866355896
#
#         # Original Example: لهذا الاعلام سقط مستواه فالحضيض لأن من يتصدر مشهده الآن لا علاقة له بالإعلام
#           > Predication Label: Neutral
#           > Predication Score: 0.9444688558578491
#             * Targeted Word: مشهده
#             * Synonym Word: الساحة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: لهذا الاعلام سقط مستواه فالحضيض لأن من يتصدر الساحة الآن لا علاقة له بالإعلام
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.6667415499687195
#
#         # Original Example: ياااا طارق هو بعد اللي عملوووو منتظر منهم يعمله فيهم ايه
#           > Predication Label: Negative
#           > Predication Score: 0.7369828224182129
#             * Targeted Word: فيهم
#             * Synonym Word: ##م
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ياااا طارق هو بعد اللي عملوووو منتظر منهم يعمله ##م ايه
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.7062501907348633
#
#         # Original Example: : حملة التجمع النسائي الديمقراطي اللبناني مش_قبل_ال١٨ تفوز بجائزة دبي لينكس! …
#           > Predication Label: Negative
#           > Predication Score: 0.4916582405567169
#             * Targeted Word: النسائي
#             * Synonym Word: الوطني
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : حملة التجمع الوطني الديمقراطي اللبناني مش_قبل_ال١٨ تفوز بجائزة دبي لينكس! …
#           < Adversarial Label:  Positive
#           < Adversarial Score:  0.4019222557544708
#
#         # Original Example: هاديك غالبا خرجو عيالات فنيااااانات مباغينش يخدمو على ريوسهن باش يلقاو لي يصرف عليهن
#           > Predication Label: Neutral
#           > Predication Score: 0.8620879650115967
#             * Targeted Word: يلقاو
#             * Synonym Word: هو
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: هاديك غالبا خرجو عيالات فنيااااانات مباغينش يخدمو على ريوسهن باش هو لي يصرف عليهن
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.5047620534896851
#
#    ## Attack Results:
#         # Model: BERT
#         # Dataset: MSDA
#           > Accuracy Before Attack (via Truth Labels): 85.0 %
#           > Accuracy Before Attack (via Predication Scores): 88.62 %
#           < Accuracy After Attack (via Predication Labels): 74.0 %
#           < Accuracy After Attack (via Predication Scores): 65.98 %
#
#
# CPU times: user 3h 42min 34s, sys: 36min 11s, total: 4h 18min 45s
# Wall time: 2h 49min 58s

# %%
# %%time

from bert_attack import *

min_length = 30
max_length = 300
number_examples = 100

datasets = ['hard', 'msda']
models = [ 'cnn']#, 'bert', 'bilstm']

main(models, datasets, min_length, max_length, number_examples)

# %%
# %%time

from bert_attack import *

min_length = 30
max_length = 300
number_examples = 100

datasets = ['hard', 'msda']
models = ['bilstm']#, 'cnn', 'bert']

main(models, datasets, min_length, max_length, number_examples)
