# %%
# %%time

from bert_attack import *

min_length = 30
max_length = 300
number_examples = 100

models = ['bilstm']
datasets = ['hard']

main(models, datasets, min_length, max_length, number_examples)
# Out:
# @@@ BEGINNING ATTACK: [ MODEL: `BILSTM` | DATASET: `HARD` ] @@@
#
#    ## Sampling Examples from `HARD` Dataset:
#       # Total Number of Qualified Examples: 44,804
#       # Total Number of Randomly Selected Examples: 100
#
#    ## Running BERT Synonym-level Attack on `BILSTM` Model:
#         # Original Example: “جيدة جدا”. . بوفيه الأفطار لم يراعى اختلاف الأذواق
#           > Predication Label: Fair
#           > Predication Score: 0.2712674140930176
#             * Targeted Word: الأذواق
#             * Synonym Word: الوجبات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيدة جدا”. . بوفيه الأفطار لم يراعى اختلاف الوجبات
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.272095263004303
#
#         # Original Example: جيد. هدوء الغرفة قربه من الحرم. النت لا يوجد عدم وجود اماكن لوقوف السيارات
#           > Predication Label: Good
#           > Predication Score: 0.3304192125797272
#             * Targeted Word: هدوء
#             * Synonym Word: سعر
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. سعر الغرفة قربه من الحرم. النت لا يوجد عدم وجود اماكن لوقوف السيارات
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.299340158700943
#
#         # Original Example: “العمرة في المروة ريحان”. الاكل ممتاز ومنوع. الحمامات  لا يتم تنظيفها جيدا /واي فاي مدفوع
#           > Predication Label: Excellent
#           > Predication Score: 0.2783474326133728
#             * Targeted Word: المروة
#             * Synonym Word: ام
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “العمرة في ام ريحان”. الاكل ممتاز ومنوع. الحمامات لا يتم تنظيفها جيدا /واي فاي مدفوع
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.26672130823135376
#
#         # Original Example: مخيب للأمل. كان الافطار جيدجدا. الموقع
#           > Predication Label: Fair
#           > Predication Score: 0.2743614614009857
#             * Targeted Word: الموقع
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مخيب للأمل. كان الافطار جيدجدا. .
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2597244679927826
#
#         # Original Example: “مناسب جدا  للعائلات”. اعجبني المكان بشكل عامسوف احجز فيه في المره القادمه. وجود الكثير من القطط و الباعوض
#           > Predication Label: Excellent
#           > Predication Score: 0.29242274165153503
#             * Targeted Word: جدا
#             * Synonym Word: ##ه
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “مناسب ##ه للعائلات”. اعجبني المكان بشكل عامسوف احجز فيه في المره القادمه. وجود الكثير من القطط و الباعوض
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.26568514108657837
#
#         # Original Example: استثنائي. كل شي تقريباً. الواي فاي يقطع احياناً
#           > Predication Label: Excellent
#           > Predication Score: 0.27301713824272156
#             * Targeted Word: شي
#             * Synonym Word: ما
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. كل ما تقريباً. الواي فاي يقطع احياناً
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2780497074127197
#
#         # Original Example: “متعة الاستجمام”. . اشتراط عمر ٢٠ سنة للاستفادة من النادي؟؟
#           > Predication Label: Fair
#           > Predication Score: 0.2615257799625397
#             * Targeted Word: عمر
#             * Synonym Word: ال
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “متعة الاستجمام”. . اشتراط ال ٢٠ سنة للاستفادة من النادي؟؟
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.26310575008392334
#
#         # Original Example: “تجربه سيئه”. . القيمة جدا مبالغ فيها مقابل الخدمة .. والتاخر للمغادره لساعه يكلفك ٢٥٪‏ من قيمة الايجار اليومي !!
#           > Predication Label: Fair
#           > Predication Score: 0.30384209752082825
#             * Targeted Word: مبالغ
#             * Synonym Word: مبالغا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “تجربه سيئه”. . القيمة جدا مبالغا فيها مقابل الخدمة .. والتاخر للمغادره لساعه يكلفك ٢٥٪‏ من قيمة الايجار اليومي !!
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2595680058002472
#
#         # Original Example: “ممتاز ومكان جميل للاقامة فيه”. الجناح وموقع الفندق ومرافقه.
#           > Predication Label: Excellent
#           > Predication Score: 0.29238006472587585
#             * Targeted Word: وموقع
#             * Synonym Word: داخل
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ممتاز ومكان جميل للاقامة فيه”. الجناح داخل الفندق ومرافقه.
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2738898694515228
#
#         # Original Example: “تجربه متوسطة”. الشقه وسيعهوبشاشة الموظفين. المسبح كان مغلق أثناء السكن بحجةيوجد رائحة في الشقهالنظافه دون المتوسط
#           > Predication Label: Fair
#           > Predication Score: 0.28881189227104187
#             * Targeted Word: السكن
#             * Synonym Word: النز
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “تجربه متوسطة”. الشقه وسيعهوبشاشة الموظفين. المسبح كان مغلق أثناء النز بحجةيوجد رائحة في الشقهالنظافه دون المتوسط
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2697294056415558
#
#         # Original Example: “قندق سئي”. بشاشه الموظفين. كل شي سئي في الفندق
#           > Predication Label: Excellent
#           > Predication Score: 0.31213080883026123
#             * Targeted Word: بشاشه
#             * Synonym Word: احد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “قندق سئي”. احد الموظفين. كل شي سئي في الفندق
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.3011230528354645
#
#         # Original Example: استثنائي. تعامل الموظفين جدا راقي اشكركم من الاعماق. ازعاج الاجانب فقط
#           > Predication Label: Fair
#           > Predication Score: 0.2704928517341614
#             * Targeted Word: ازعاج
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. تعامل الموظفين جدا راقي اشكركم من الاعماق. . الاجانب فقط
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.26959261298179626
#
#         # Original Example: “جيد”. موقف السيارة. السرير صغير جداً
#           > Predication Label: Fair
#           > Predication Score: 0.2874545156955719
#             * Targeted Word: موقف
#             * Synonym Word: لون
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيد”. لون السيارة. السرير صغير جداً
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2622053921222687
#
#         # Original Example: “قمة في المستوى والرقي”. كل شي ممتاز. وقت الخروج يجب تغييره
#           > Predication Label: Fair
#           > Predication Score: 0.29779312014579773
#             * Targeted Word: المستوى
#             * Synonym Word: الفخامة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “قمة في الفخامة والرقي”. كل شي ممتاز. وقت الخروج يجب تغييره
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2972685396671295
#
#         # Original Example: ضعيف. . أتوبيسات المؤدية للحرم غير متوفرة ومواعيدها سيئه
#           > Predication Label: Fair
#           > Predication Score: 0.26673078536987305
#             * Targeted Word: للحرم
#             * Synonym Word: الصحى
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ضعيف. . أتوبيسات المؤدية الصحى غير متوفرة ومواعيدها سيئه
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2649313807487488
#
#         # Original Example: “سيء جدا”. إهمال عدم راحة . تسببو بخدش سيارتي. كل شي
#           > Predication Label: Fair
#           > Predication Score: 0.26952579617500305
#             * Targeted Word: عدم
#             * Synonym Word: وقلة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “سيء جدا”. إهمال وقلة راحة . تسببو بخدش سيارتي. كل شي
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.27876439690589905
#
#         # Original Example: ضعيف جداً. لاشيء. لايوجد عوازل صوت في الغرفة حوض الاستحمام تالف
#           > Predication Label: Good
#           > Predication Score: 0.2800646722316742
#             * Targeted Word: الاستحمام
#             * Synonym Word: السباحة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ضعيف جداً. لاشيء. لايوجد عوازل صوت في الغرفة حوض السباحة تالف
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.28565284609794617
#
#         # Original Example: “مكان حلو وسعره حلو”. سرير النوم والمكيف بارد. مافيه منديل
#           > Predication Label: Good
#           > Predication Score: 0.28920382261276245
#             * Targeted Word: النوم
#             * Synonym Word: مريح
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “مكان حلو وسعره حلو”. سرير مريح والمكيف بارد. مافيه منديل
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2806181311607361
#
#         # Original Example: “فعلا يستحق 5 نجوم”. الهدوء والإسترخاء. موقف السياره يحتاج ان تخبر السيكيوريتي الموجود امام الفندق ليتوجه الى الموقف لفتح البوابه
#           > Predication Label: Excellent
#           > Predication Score: 0.2933342754840851
#             * Targeted Word: الهدوء
#             * Synonym Word: الراحة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فعلا يستحق 5 نجوم”. الراحة والإسترخاء. موقف السياره يحتاج ان تخبر السيكيوريتي الموجود امام الفندق ليتوجه الى الموقف لفتح البوابه
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2742585241794586
#
#         # Original Example: “اسوء فندق زرته”. لم يعجبني شيء. كل شيء
#           > Predication Label: Poor
#           > Predication Score: 0.267928808927536
#             * Targeted Word: فندق
#             * Synonym Word: مكان
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “اسوء مكان زرته”. لم يعجبني شيء. كل شيء
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2704804539680481
#
#         # Original Example: رائع. حلو ومرتب ومناسب للعائلات الي معاهم سياره وفي مطاعم وسوبرماركت قريب. موقعه بعيد عن دبي مول وشارع الشيخ زايد
#           > Predication Label: Excellent
#           > Predication Score: 0.33475959300994873
#             * Targeted Word: ومرتب
#             * Synonym Word: السعر
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: رائع. حلو السعر ومناسب للعائلات الي معاهم سياره وفي مطاعم وسوبرماركت قريب. موقعه بعيد عن دبي مول وشارع الشيخ زايد
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.30573222041130066
#
#         # Original Example: جيد. . عدم دقة المواصلات يا ريت يبقي في اهتمام اكثر بها
#           > Predication Label: Fair
#           > Predication Score: 0.32204529643058777
#             * Targeted Word: عدم
#             * Synonym Word: ولكن
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. . ولكن دقة المواصلات يا ريت يبقي في اهتمام اكثر بها
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2860316336154938
#
#         # Original Example: جيد جداً. . عدم امكانية فتح النوافذ للتجديد الهواء
#           > Predication Label: Good
#           > Predication Score: 0.2900405824184418
#             * Targeted Word: الهواء
#             * Synonym Word: !
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد جداً. . عدم امكانية فتح النوافذ للتجديد !
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.28863874077796936
#
#         # Original Example: جيد. دخول الغرفة في وقت مبكر. صغر حجم الغرفةعدم وجود أسرة كبيرة
#           > Predication Label: Fair
#           > Predication Score: 0.2811221778392792
#             * Targeted Word: دخول
#             * Synonym Word: وصول
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. وصول الغرفة في وقت مبكر. صغر حجم الغرفةعدم وجود أسرة كبيرة
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.27133893966674805
#
#         # Original Example: “ممتاز”. فندق رائع بكل ماتعنيه الكلمة والوصف يتميز بطابع المودرن والفخامة والراحة والهدوء. لاشيئ
#           > Predication Label: Excellent
#           > Predication Score: 0.40634092688560486
#             * Targeted Word: رائع
#             * Synonym Word: مميز
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ممتاز”. فندق مميز بكل ماتعنيه الكلمة والوصف يتميز بطابع المودرن والفخامة والراحة والهدوء. لاشيئ
#           < Adversarial Label:  Poor
#           < Adversarial Score:  0.27218347787857056
#
#         # Original Example: “الفندق في غير مستواه ... ولا يرتقي لان يكون ذو 5 او 4 نجوم”. طاقم العمل. النظافة سيئة جدا
#           > Predication Label: Fair
#           > Predication Score: 0.34028002619743347
#             * Targeted Word: مستواه
#             * Synonym Word: الممتاز
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “الفندق في غير الممتاز ... ولا يرتقي لان يكون ذو 5 او 4 نجوم”. طاقم العمل. النظافة سيئة جدا
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.3158934712409973
#
#         # Original Example: “جيد جدا”. حسن المعامله سرعه الخدمهل. لايوجد
#           > Predication Label: Excellent
#           > Predication Score: 0.3503081202507019
#             * Targeted Word: حسن
#             * Synonym Word: مستوى
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “جيد جدا”. مستوى المعامله سرعه الخدمهل. لايوجد
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.29690974950790405
#
#         # Original Example: استثنائي. . -الحمام لا يوجد فيه شطاف خاص بالكرسي الافرنجي ؟-الحمام جدرانه من زجاج جميل ولكن الستارة خفيفة ؟
#           > Predication Label: Excellent
#           > Predication Score: 0.27286186814308167
#             * Targeted Word: خاص
#             * Synonym Word: فكيف
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. . -الحمام لا يوجد فيه شطاف فكيف بالكرسي الافرنجي ؟-الحمام جدرانه من زجاج جميل ولكن الستارة خفيفة ؟
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2748577892780304
#
#         # Original Example: “رائع”. كل شئ. لاشئ سوى الحفريات التي تتم قرب الفندق مما صعب الوصول للموقع
#           > Predication Label: Fair
#           > Predication Score: 0.28943803906440735
#             * Targeted Word: لاشئ
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “رائع”. كل شئ. . سوى الحفريات التي تتم قرب الفندق مما صعب الوصول للموقع
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2683965563774109
#
#         # Original Example: جيد جداً. قربه من الحرمتعامل الطاقم. بعده عن المواصلات العامه بالاخص اوقات الزحمه ايضا لايوجد توصيل للمطار باسعار معقوله
#           > Predication Label: Good
#           > Predication Score: 0.30625492334365845
#             * Targeted Word: قربه
#             * Synonym Word: قريب
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد جداً. قريب من الحرمتعامل الطاقم. بعده عن المواصلات العامه بالاخص اوقات الزحمه ايضا لايوجد توصيل للمطار باسعار معقوله
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.29633012413978577
#
#         # Original Example: مخيب للأمل. المساحة. طاقم العمل بالأستقبال والخدمة المقدمة
#           > Predication Label: Fair
#           > Predication Score: 0.2740190029144287
#             * Targeted Word: العمل
#             * Synonym Word: رائع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مخيب للأمل. المساحة. طاقم رائع بالأستقبال والخدمة المقدمة
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.34239599108695984
#
#         # Original Example: جيد. موظفين الاستقبال والشاطئ والمطاعم كانت كلها ممتازة.
#           > Predication Label: Good
#           > Predication Score: 0.293620765209198
#             * Targeted Word: والمطاعم
#             * Synonym Word: ،
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. موظفين الاستقبال والشاطئ ، كانت كلها ممتازة.
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2871095538139343
#
#         # Original Example: جيد جداً. قربه من جامعو مطاعم و تسويقو توجد باصات للحرم تضيعها لما ترجع.
#           > Predication Label: Good
#           > Predication Score: 0.27715498208999634
#             * Targeted Word: للحرم
#             * Synonym Word: لا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد جداً. قربه من جامعو مطاعم و تسويقو توجد باصات لا تضيعها لما ترجع.
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2824403643608093
#
#         # Original Example: استثنائي. الهدوء والموقع المناسب ، تصميم الفندق رائع.
#           > Predication Label: Excellent
#           > Predication Score: 0.3075246810913086
#             * Targeted Word: الهدوء
#             * Synonym Word: الموقع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: استثنائي. الموقع والموقع المناسب ، تصميم الفندق رائع.
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.27668556571006775
#
#         # Original Example: “عادي جداً وسعره مبالغ فيه”. السرير رائع الهدوء قريب مسجد قباء 7 دتلبية الطلبات. طاقم العمل يحتاج الى تدريب المواقف بالشمس وضيقةالخدمات بعيده نوعاً ماالتاخير في تلبية الطلباتالهاتف لا يتصل خارج الفندق
#           > Predication Label: Excellent
#           > Predication Score: 0.3651842772960663
#             * Targeted Word: رائع
#             * Synonym Word: متوسط
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “عادي جداً وسعره مبالغ فيه”. السرير متوسط الهدوء قريب مسجد قباء 7 دتلبية الطلبات. طاقم العمل يحتاج الى تدريب المواقف بالشمس وضيقةالخدمات بعيده نوعاً ماالتاخير في تلبية الطلباتالهاتف لا يتصل خارج الفندق
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.302733451128006
#
#         # Original Example: “روعة الفندق”. جميل بمعنى الكلمة الافطار منوع ولذيذ. لاتوجد
#           > Predication Label: Excellent
#           > Predication Score: 0.2933506965637207
#             * Targeted Word: منوع
#             * Synonym Word: جيد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “روعة الفندق”. جميل بمعنى الكلمة الافطار جيد ولذيذ. لاتوجد
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2710717022418976
#
#         # Original Example: ممتاز. . تأخير رفع اطباق الطعام من امام الباب
#           > Predication Label: Good
#           > Predication Score: 0.27392926812171936
#             * Targeted Word: اطباق
#             * Synonym Word: طاولة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ممتاز. . تأخير رفع طاولة الطعام من امام الباب
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.27333900332450867
#
#         # Original Example: “راحة واستجمام”. كل شيئ بالفندق ورحابة الاستقبال من قبل الموظف ياسين بالاستقبال. عدم توفر الإنترنت مجانا في الغرف او اللوبي
#           > Predication Label: Excellent
#           > Predication Score: 0.28088703751564026
#             * Targeted Word: مجانا
#             * Synonym Word: سواء
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “راحة واستجمام”. كل شيئ بالفندق ورحابة الاستقبال من قبل الموظف ياسين بالاستقبال. عدم توفر الإنترنت سواء في الغرف او اللوبي
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.26727738976478577
#
#         # Original Example: “زياره سيدنا محمد”. نظافه.  قرب من الحرم. فطور متنوع. موقع فندق صعب وصول
#           > Predication Label: Good
#           > Predication Score: 0.269773006439209
#             * Targeted Word: صعب
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “زياره سيدنا محمد”. نظافه. قرب من الحرم. فطور متنوع. موقع فندق . وصول
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.27568838000297546
#
#         # Original Example: “لاانصح في الفندق”. مسئول الكراج اخلاق عالية. تعامل الرسبشن وعمال الخدمة
#           > Predication Label: Fair
#           > Predication Score: 0.3186835050582886
#             * Targeted Word: وعمال
#             * Synonym Word: وحسن
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “لاانصح في الفندق”. مسئول الكراج اخلاق عالية. تعامل الرسبشن وحسن الخدمة
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.2791736125946045
#
#         # Original Example: “بالنسبة للسعر جيد”. المكان قريب لوسط البلد والجراج الخاص بالسيارات. موظف الإستقبال والنظافة
#           > Predication Label: Fair
#           > Predication Score: 0.291521817445755
#             * Targeted Word: موظف
#             * Synonym Word: حسن
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “بالنسبة للسعر جيد”. المكان قريب لوسط البلد والجراج الخاص بالسيارات. حسن الإستقبال والنظافة
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.30285221338272095
#
#         # Original Example: مخيب للأمل. . الاستقبال لايستجيب كثيراً
#           > Predication Label: Fair
#           > Predication Score: 0.3000113368034363
#             * Targeted Word: الاستقبال
#             * Synonym Word: ولكن
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مخيب للأمل. . ولكن لايستجيب كثيراً
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.26296475529670715
#
#         # Original Example: ضعيف. شاطئ البحر. سكن بخرابة احسن من هذا الفندق
#           > Predication Label: Excellent
#           > Predication Score: 0.28160566091537476
#             * Targeted Word: شاطئ
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ضعيف. . البحر. سكن بخرابة احسن من هذا الفندق
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.266000360250473
#
#         # Original Example: “فندق مميز”. يتميز بالطاقم المرح والمبتسم والخدوم جداً. لا شي
#           > Predication Label: Excellent
#           > Predication Score: 0.27591758966445923
#             * Targeted Word: المرح
#             * Synonym Word: المميز
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فندق مميز”. يتميز بالطاقم المميز والمبتسم والخدوم جداً. لا شي
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.25879934430122375
#
#         # Original Example: جيد. النظافه والسعر وطاقم العمل خدومين. المسبح غير نظيف وكميه الكلور فيه كبيره
#           > Predication Label: Excellent
#           > Predication Score: 0.2818887233734131
#             * Targeted Word: العمل
#             * Synonym Word: العمال
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: جيد. النظافه والسعر وطاقم العمال خدومين. المسبح غير نظيف وكميه الكلور فيه كبيره
#           < Adversarial Label:  Good
#           < Adversarial Score:  0.2830500304698944
#
#         # Original Example: “ممتاز جدا”. تعامل الاخت لطيفه ومحمود ومحمد.
#           > Predication Label: Fair
#           > Predication Score: 0.26322150230407715
#             * Targeted Word: تعامل
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “ممتاز جدا”. . الاخت لطيفه ومحمود ومحمد.
#           < Adversarial Label:  Excellent
#           < Adversarial Score:  0.27554526925086975
#
#         # Original Example: “فاشل جداً”. . المكان كان سيء جداً و طاقم العمل لا يحترمون الزباين
#           > Predication Label: Excellent
#           > Predication Score: 0.2732907831668854
#             * Targeted Word: العمل
#             * Synonym Word: الفندق
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: “فاشل جداً”. . المكان كان سيء جداً و طاقم الفندق لا يحترمون الزباين
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.2654675841331482
#
#         # Original Example: ممتاز. جميل وموقعه رائع. الواي فاي بفلوس
#           > Predication Label: Excellent
#           > Predication Score: 0.2831893861293793
#             * Targeted Word: وموقعه
#             * Synonym Word: .
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ممتاز. جميل . رائع. الواي فاي بفلوس
#           < Adversarial Label:  Fair
#           < Adversarial Score:  0.261006623506546
#
#    ## Attack Results:
#         # Model: BILSTM
#         # Dataset: HARD
#           > Accuracy Before Attack (via Truth Labels): 54.0 %
#           > Accuracy Before Attack (via Predication Scores): 31.03 %
#           < Accuracy After Attack (via Predication Labels): 52.0 %
#           < Accuracy After Attack (via Predication Scores): 27.92 %
#
#
# CPU times: user 7h 26min 50s, sys: 11min 30s, total: 7h 38min 21s
# Wall time: 7h 42min 34s

# %%
# %%time

from bert_attack import *

min_length = 30
max_length = 300
number_examples = 100

models = ['bilstm']
datasets = ['msda']

main(models, datasets, min_length, max_length, number_examples)
# Out:
# @@@ BEGINNING ATTACK: [ MODEL: `BILSTM` | DATASET: `MSDA` ] @@@
#
#    ## Sampling Examples from `MSDA` Dataset:
#       # Total Number of Qualified Examples: 17,424
#       # Total Number of Randomly Selected Examples: 100
#
#    ## Running BERT Synonym-level Attack on `BILSTM` Model:
#         # Original Example: كله طلع مجرد شعارات أرهقونا بها العفو يا أم محمد ❤
#           > Predication Label: Neutral
#           > Predication Score: 0.3807845711708069
#             * Targeted Word: طلع
#             * Synonym Word: أصبح
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: كله أصبح مجرد شعارات أرهقونا بها العفو يا أم محمد ❤
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.39726585149765015
#
#         # Original Example: صحيح .. والد صلاح دياب (نيوتن) مالك المصرى اليوم
#           > Predication Label: Negative
#           > Predication Score: 0.38910195231437683
#             * Targeted Word: دياب
#             * Synonym Word: سالم
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: صحيح .. والد صلاح سالم (نيوتن) مالك المصرى اليوم
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.38668587803840637
#
#         # Original Example: عيد ميلاد سعيد بطول العمر و كل المتمنيات 🎉🎊🎊🌹🌹
#           > Predication Label: Negative
#           > Predication Score: 0.3689970076084137
#             * Targeted Word: المتمنيات
#             * Synonym Word: عام
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: عيد ميلاد سعيد بطول العمر و كل عام 🎉🎊🎊🌹🌹
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3434634804725647
#
#         # Original Example: حمدالله حمدا كثيرا رب يغيثنا بالغيث النافع المدرار 🙏
#           > Predication Label: Neutral
#           > Predication Score: 0.447208970785141
#             * Targeted Word: حمدالله
#             * Synonym Word: الله
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: الله حمدا كثيرا رب يغيثنا بالغيث النافع المدرار 🙏
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.37389087677001953
#
#         # Original Example: : 👌 pouvoir_assassin تروح_كورونا_زيدو_أنتوما توقفوا_عن_استدعاء_النشطاء الحرية_لمعتقلي_الرٱي
#           > Predication Label: Neutral
#           > Predication Score: 0.4837067127227783
#             * Targeted Word: الحرية_لمعتقلي_الرٱي
#             * Synonym Word: _
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : 👌 pouvoir_assassin تروح_كورونا_زيدو_أنتوما توقفوا_عن_استدعاء_النشطاء _
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.3798505663871765
#
#         # Original Example: عاشر يا بو معاشر و لابد من الفرقة... -مقصودة😔😞😎
#           > Predication Label: Neutral
#           > Predication Score: 0.423092782497406
#             * Targeted Word: معاشر
#             * Synonym Word: سعد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: عاشر يا بو سعد و لابد من الفرقة... -مقصودة😔😞😎
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.3774144947528839
#
#         # Original Example: ممنوع للعامة بس الاعلام مسمحله ببعض الحالات حسب ما فهمت من الاصدقاء والصديقات 🤷‍♀️
#           > Predication Label: Negative
#           > Predication Score: 0.4783804714679718
#             * Targeted Word: الاعلام
#             * Synonym Word: انا
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: ممنوع للعامة بس انا مسمحله ببعض الحالات حسب ما فهمت من الاصدقاء والصديقات 🤷‍♀️
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3811865746974945
#
#         # Original Example: شغل فاخر من الاخر تدوم يارب تحياتي هي ديه اسلحتهم وكلنا عارفين افكارهم
#           > Predication Label: Negative
#           > Predication Score: 0.38711926341056824
#             * Targeted Word: يارب
#             * Synonym Word: مع
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: شغل فاخر من الاخر تدوم مع تحياتي هي ديه اسلحتهم وكلنا عارفين افكارهم
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.39486226439476013
#
#         # Original Example: : بصراحة .. أنا بدأت أشك فى كلام عماد 😂😂
#           > Predication Label: Neutral
#           > Predication Score: 0.4236368238925934
#             * Targeted Word: كلام
#             * Synonym Word: قدرات
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : بصراحة .. أنا بدأت أشك فى قدرات عماد 😂😂
#           < Adversarial Label:  Negative
#           < Adversarial Score:  0.38123369216918945
#
#         # Original Example: عيدك مبارك كل عام وانتم بالف خير يارب
#           > Predication Label: Positive
#           > Predication Score: 0.4549959897994995
#             * Targeted Word: عام
#             * Synonym Word: سنة
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: عيدك مبارك كل سنة وانتم بالف خير يارب
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.351362019777298
#
#         # Original Example: مقالتي اليوم في الجمهورية وداعاً سمير_يزبك الصوت «الموجوع» يلتحق بالعمالقة
#           > Predication Label: Negative
#           > Predication Score: 0.39504456520080566
#             * Targeted Word: الجمهورية
#             * Synonym Word: العدد
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: مقالتي اليوم في العدد وداعاً سمير_يزبك الصوت «الموجوع» يلتحق بالعمالقة
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3938864767551422
#
#         # Original Example: : كل واحد يركز فى ورقته الإمتحان صعب يا أمريكا
#           > Predication Label: Negative
#           > Predication Score: 0.38791465759277344
#             * Targeted Word: أمريكا
#             * Synonym Word: دكتور
#         ----------------------------------------------
#         ***** SUCCESSFUL ATTACK FOUND & RECORDED *****
#         ----------------------------------------------
#         # Adversarial Example: : كل واحد يركز فى ورقته الإمتحان صعب يا دكتور
#           < Adversarial Label:  Neutral
#           < Adversarial Score:  0.3639044761657715
#
#    ## Attack Results:
#         # Model: BILSTM
#         # Dataset: MSDA
#           > Accuracy Before Attack (via Truth Labels): 66.0 %
#           > Accuracy Before Attack (via Predication Scores): 48.63 %
#           < Accuracy After Attack (via Predication Labels): 88.0 %
#           < Accuracy After Attack (via Predication Scores): 37.71 %
#
#
# CPU times: user 8h 6min 37s, sys: 12min 46s, total: 8h 19min 23s
# Wall time: 8h 24min 39s
